# %%
def allergy1(product):
    if ('새우' in product) or('게' in product) or('랍스터' in product) or('가재' in product) : name = '1'
    else: name=''
    return name

coupang['알레르기(갑각류)'] = coupang['구성정보_전처리'].apply(lambda x : allergy1(x))    

def allergy2(product):
    if ('밤' in product)or('호두' in product)or('땅콩' in product) or ('아몬드' in product) or ('잣' in product) or ('은행' in product)  or ('헤이즐넛' in product) or ('크랜베리' in product) : name = '1'
    else: name=''
    return name

coupang['알레르기(견과류)'] = coupang['구성정보_전처리'].apply(lambda x : allergy2(x))

def allergy3(product):
    if ('달걀' in product) or ('계란' in product) : name = '1'
    else: name=''
    return name

coupang['알레르기(달걀)'] = coupang['구성정보_전처리'].apply(lambda x : allergy3(x))

def allergy4(product):
    if ('밀' in product) or ('밀가루' in product) : name = '1'
    else: name=''
    return name

coupang['알레르기(밀가루)'] = coupang['구성정보_전처리'].apply(lambda x : allergy4(x))

def allergy5(product):
    if '우유' in product : name = '1'
    else: name=''
    return name

coupang['알레르기(우유)'] = coupang['구성정보_전처리'].apply(lambda x : allergy5(x))

def allergy6(product):
    if ('조개' in product) or ('홍합' in product) or ('굴' in product) or ('가리비' in product) : name = '1'
    else: name=''
    return name

coupang['알레르기(조개류)'] = coupang['구성정보_전처리'].apply(lambda x : allergy6(x))

def allergy7(product):
    if ('문어' in product) or ('오징어' in product) : name = '1'
    else: name=''
    return name

coupang['알레르기(오징어류)'] = coupang['구성정보_전처리'].apply(lambda x : allergy7(x))

def allergy8(product):
    if ('콩' in product) or ('두부' in product) or ('대두' in product): name = '1'
    else: name=''
    return name

coupang['알레르기(콩)'] = coupang['구성정보_전처리'].apply(lambda x : allergy8(x))

def allergy9(product):
    if '닭' in product : name = '1'
    else: name=''
    return name

coupang['알레르기(닭)'] = coupang['구성정보_전처리'].apply(lambda x : allergy9(x))

def allergy10(product):
    if '돼지고기' in product : name = '1'
    else: name=''
    return name

coupang['알레르기(돼지)'] = coupang['구성정보_전처리'].apply(lambda x : allergy10(x))

def allergy11(product):
    if '복숭아' in product : name = '1'
    else: name=''
    return name

coupang['알레르기(복숭아)'] = coupang['구성정보_전처리'].apply(lambda x : allergy11(x))

def allergy12(product):
    if ('소고기' in product) or ('쇠고기' in product): name = '1'
    else: name=''
    return name

coupang['알레르기(소)'] = coupang['구성정보_전처리'].apply(lambda x : allergy12(x))

def allergy13(product):
    if '토마토' in product : name = '1'
    else: name=''
    return name

coupang['알레르기(토마토)'] = coupang['구성정보_전처리'].apply(lambda x : allergy13(x))

def allergy14(product):
    if ('굴비' in product)or('조기' in product)or('고등어' in product)or('갈치' in product)or('꽁치' in product)or ('전어' in product)or ('명태' in product)or ('노가리' in product)or ('메기' in product)or('동태' in product): name = '1'
    else: name=''
    return name

coupang['알레르기(생선)'] = coupang['구성정보_전처리'].apply(lambda x : allergy14(x))

def allergy15(product):
    if '토마토' in product : name = '1'
    else: name=''
    return name

coupang['알레르기(토마토)'] = coupang['구성정보_전처리'].apply(lambda x : allergy15(x))

# %%
coupang_allergy = coupang.loc[:,['상품','알레르기(갑각류)','알레르기(견과류)','알레르기(갑각류)','알레르기(견과류)','알레르기(달걀)','알레르기(밀가루)','알레르기(우유)','알레르기(조개류)','알레르기(오징어류)','알레르기(콩)','알레르기(닭)','알레르기(돼지)','알레르기(복숭아)','알레르기(소)','알레르기(생선)','알레르기(토마토)']]
coupang_allergy

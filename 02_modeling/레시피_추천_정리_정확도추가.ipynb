# %% [markdown]
# # 레시피 추천 시스템

# %% [markdown]
# https://chan-chance.tistory.com/22

# %%
import pandas as pd
import numpy as np
import re
from pprint import pprint
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
from gensim.models import Word2Vec

# %%
coupang = pd.read_csv('../../data/coupang_filtering_pre.csv')

#가중치까지 계산한 df을 불러옴
ckg = pd.read_csv('../../data/ckg_weighted.csv', index_col=0)

#word2vec 사용을 위한 데이터 포멧 변경
ckg['요리재료_전처리'] = ckg['요리재료_전처리'].apply(lambda x : x.split(', ')) # 1차원 list 형태
ckg.head()
# Out:
#    레시피일련번호                레시피제목      요리명    조회수  추천수  스크랩수 요리방법별명 요리상황별명  \
# 0   131871               ★현미호두죽    현미호두죽   2912    0     9    끓이기     일상
# 1   139247      부들부들 보들보들 북어갈비♥     북어갈비   6865    3    97     굽기    술안주
# 2   149207             토마토스파게티♥  토마토스파게티  12754    2    36     볶음     일상
# 3   151148               표고버섯탕수   표고버섯탕수  16053    2   194     튀김   손님접대
# 4   153040  달콤한 마늘향이 가득해~ 갈릭치킨♥     갈릭치킨   8148    0    38     튀김   손님접대
#
#   요리재료별명 요리종류별명                                               요리소개  \
# 0      쌀  밥/죽/떡                                              현미호두죽
# 1   건어물류   메인반찬  오늘은 집에서 굴러다니고 쉽게 구할 수 있는 북어로 일품요리를 만들어 보았어요! 도...
# 2  가공식품류   면/만두       한번 만들어 두면 이모저모 쓸 용도가 많은 토마토소스를 이용한 토마토 스파게티.
# 3    버섯류   메인반찬  탕수육 먹을때 칼로리때문에 걱정하시는 분들!! 이제는 걱걱걱 정하지 마세요~ 칼로리...
# 4    닭고기   메인반찬  요즘 갈릭이 대세인거 같아요~ 그래서 오늘은 제가 너무 좋아하는 닭과 마늘을 한번에...
#
#                                               요리재료내용  \
# 0           [재료] 현미 4컵| 찹쌀 2컵| 호두 50g| 물 1/2컵| 소금 약간
# 1  [재료] 북어포 1마리| 찹쌀가루 1C [양념] 간장 2T| 설탕 1T| 물 1T|...
# 2  [재료] 파스타면 [양념] 토마토 1개| 토마토 페이스트 3T| 양파 1/2개| 다...
# 3  [재료] 건표고버섯 9개| 오이 1/2개| 당근 1/2개| 양파 1/2개| 사과 1...
# 4  [재료] 닭 1마리 [닭양념] 통마늘 3개| 다진마늘 1T| 화이트와인또는우유| 올...
#
#                                             요리재료_전처리      알레르기  \
# 0                                [현미, 찹쌀, 호두, 물, 소금]       견과류
# 1  [북어포, 찹쌀가루, 간장, 설탕, 물, 다진파, 다진마늘, 참기름, 깨소금, 후춧가루]    콩, 견과류
# 2               [파스타면, 토마토, 토마토, 양파, 다진마늘, 피망, 올리브유]  밀가루, 토마토
# 3  [건표고버섯, 오이, 당근, 양파, 사과, 그외의, 과일, 녹말가루, 물, 계란 노...     난류, 콩
# 4  [닭, 통마늘, 다진마늘, 화이트와인또는우유, 올리브유또는버터, 마늘솔트또는소금, ...     우유, 닭
#
#    weighted_clipping
# 0         314.655903
# 1         284.844463
# 2         212.802388
# 3         279.114241
# 4         251.350570

# %%
# coupang[coupang.상세카테고리 == '']
coupang[coupang.상품.str.contains('아귀')]
# Out:
#      Unnamed: 0.1  Unnamed: 0  level_0  index  카테고리명        상품id  \
# 29             29          29       29     29      1  6909266222
# 35             35          35       35     35      1  6909265763
# 117           117         117      229    232      7  6776710132
# 127           127         127      239    242      7  6850319048
#
#      data-item-id  data-vendor-item-id                                     상품  \
# 29    16645171576          83829265080     바다자리 생물 아귀 맑은탕 씨키트 2~3인분 900g + 야채
# 35    16645168518          83829261628      바다자리 생물 아귀 매운탕 씨키트 2~3인분 1kg + 야채
# 117   15925063267          83132276737             The 푸짐한 찜선생 아귀찜 3~4인분 (냉동)
# 127   16317264703          83509417100  바다자리 매콤한 순살아귀 불고기 + 야채 + 소스 씨키트 2~3인분
#
#                                                  상품명  ...        100g당_가격  \
# 29           바다자리 생물 아귀 맑은탕 씨키트 2~3인분 900g + 야채, 1세트  ...             NaN
# 35            바다자리 생물 아귀 매운탕 씨키트 2~3인분 1kg + 야채, 1세트  ...             NaN
# 117              The 푸짐한 찜선생 아귀찜 3~4인분 (냉동), 1kg, 1개  ...  (100g당 1,610원)
# 127  바다자리 매콤한 순살아귀 불고기 + 야채 + 소스 씨키트 2~3인분, 350g, 1개  ...  (100g당 4,757원)
#
#       별점  리뷰수 품절여부                                               구성정보  \
# 29   4.5   35    0  아귀, 바지락, 야채세트(콩나물, 미나리, 파, 고추, 무), 바른마늘, 바지락맛 ...
# 35   5.0   11    0  아귀, 바지락, 홍합, 야채세트(콩나물, 미나리, 파, 고추, 무), 바른마늘, 해...
# 117  4.5   72    0           아귀, 대구 곤이, 흰다리새우, 주름 미더덕과 소스로 구성되어 있습니다.
# 127  4.5  303    0  순살 아귀, 야채 세트(양배추, 양파, 고추, 파, 마늘), 새댁표 고추맛기름, 화...
#
#                             구성정보_전처리  상세카테고리           알레르기 weighted_rating  \
# 29   아귀,바지락,콩나물,미나리,파,고추,무,바지락맛 액상소스     생선탕  연체동물류, 생선류, 콩        4.443753
# 35   아귀,바지락,홍합,콩나물,미나리,파,고추,무,해물탕 양념     생선탕  연체동물류, 생선류, 콩        4.457965
# 117                 아귀,대구곤이,흰다리새우,소스       찜       갑각류, 생선류        4.449648
# 127           양배추,양파,고추,파,마늘,화유,하얀설탕      한식            생선류        4.469565
#
#                                      상품_전처리
# 29      바다자리 생물 아귀 맑은탕 씨키트 2~3인분 900 g + 야채
# 35       바다자리 생물 아귀 매운탕 씨키트 2~3인분 1 kg + 야채
# 117          The 푸짐한 찜선생 아귀찜 3 ~ 4인분 ( 냉동 )
# 127  바다자리 매콤한 순살 아귀 불고기 + 야채 + 소스 씨키트 2~3인분
#
# [4 rows x 23 columns]

# %%
a = ckg[ckg.요리명.str.contains('해장')]
a#[a.요리방법별명 == '찜']
# Out:
#        레시피일련번호                                           레시피제목        요리명  \
# 1477   1545709               아침국  해장국으로 좋은 시원하고 감칠맛나는 콩나물국 끓이기     콩나물해장국
# 2084   1674596                                   콩나물 해장라면 만들기     콩나물해장라면
# 2193   1689906                                속풀이 해장국으로 좋은 황태국      황태해장국
# 2246   1697618                                   홈메이드 뜨끈한 뼈해장국       뼈해장국
# 3163   1826505                                      선지 해장국 끓이기      선지해장국
# ...        ...                                             ...        ...
# 95185  6948805                               무청시래기 뼈해장국~겨울 보양식  무청시래기뼈해장국
# 95302  6948970                          다슬기국 올갱이해장국 보약 한그릇 집에서     올갱이해장국
# 95327  6949005                         감자탕 끓이는법 묵은지요리 돼지등뼈 해장국    돼지등뼈해장국
# 96179  6950175  #소위요리 #양평해장국만들기 #삶아낸 소위와 양지를 넣고 시원하게 끓여낸 양평해장국      양평해장국
# 97278  6951651                       든든한 한끼~!! 집에서 뼈다귀 해장국 만들기     뼈다귀해장국
#
#          조회수  추천수  스크랩수 요리방법별명 요리상황별명 요리재료별명 요리종류별명  \
# 1477   20511    7   115    끓이기     일상    채소류    국/탕
# 2084   69113    8   289    끓이기     야식    채소류   면/만두
# 2193   30066   17   280    끓이기     해장   건어물류    국/탕
# 2246   55562   28  1334    끓이기     해장     육류    국/탕
# 3163   49680   20   221    끓이기     해장     육류    국/탕
# ...      ...  ...   ...    ...    ...    ...    ...
# 95185   1435    0    25    끓이기    영양식   돼지고기    국/탕
# 95302   2982    0    30    끓이기    영양식     기타    국/탕
# 95327   1640    0    25    끓이기    영양식   돼지고기    국/탕
# 96179   3740    0    14    끓이기     해장    소고기    국/탕
# 97278   1499    0    18    끓이기   손님접대   돼지고기    국/탕
#
#                                                     요리소개  \
# 1477                   아침국  해장국으로 좋은 시원하고 감칠맛나는 콩나물국입니다.
# 2084   야식으로 먹었던 콩나물 라면이에요. 면에 콩나물 하나 넣은 것 뿐인데 기름기도 적어...
# 2193                            시원한 속풀이 해장국으로 좋은 황태국입니다.
# 2246   뜨끈한 뚝배기 뼈다귀해장국 만들어 봤어요. 무작정 핏물부터 빼면서 인터넷 찾아봤는데...
# 3163                                 선지해장국을 집에서 끓여보겠습니다.
# ...                                                  ...
# 95185     예로부터 겨울먹거리 무청시래기에 돼지등뼈를 푹 끓여서 뜨끈하게 해장국 한그릇해보세요
# 95302  저는 경상도에서 자라서 어릴때는 할머니댁에 농사를 지으시니 주말마다 들어가서 놀았어...
# 95327                       뜨끈한 국물이 최고인 감자탕 맛있게 만들어 볼께요.
# 96179  양평해장국의 특징이 선지가 들어가지 않는 것이지요.  물론 선지를 넣어 주는 곳도 ...
# 97278  돼지등뼈와 건시래기를 가지고 뼈다귀 해장국을 만들어 보았습니다. 뼈다귀 해장국은 조...
#
#                                                   요리재료내용  \
# 1477   [재료] 콩나물| 양파(중) 1/4개| 쪽파 약간 | [멸치다시마 육수]| 멸치 1...
# 2084   [재료] 라면 (소 84g) 2봉지| 콩나물 120g(취향껏)| 대파| 풋고추| 홍...
# 2193   [재료] 황태 50g| 다시마육수 3큰술| 무우 50~70g| 계란 1개| 다진마늘...
# 2246   [재료] 국내산 냉장 돼지등뼈 1.5kg| 우거지 200g| 대파 2뿌리| 양파 1...
# 3163   [재료] 선지 2공기| 얼갈이 1/2단| 양 1장| 청양고추 5개| 대파 1+1/2...
# ...                                                  ...
# 95185  [재료] 돼지등뼈 4~5kg| 무청 우거지 800g| 월계수잎 7~8장| 편생강 1...
# 95302  [재료] 배추잎 6장| 부추 1줌| 파 1대| 청양고추 2개| 양파 1/2개| 된장...
# 95327  [재료] 돼지등뼈 1.5kg| 설탕 1/3컵| 간마늘1T| 된장1T| 고춧가루2T|...
# 96179  [재료] 소위 600g| 한우양지 500g| 통마늘 10개| 대파 4대| 콩나물 1...
# 97278  [뼈다귀해장국 재료] 돼지등뼈 1.5kg| 월계수잎 10장| 건시래기 200g| 양...
#
#                                                 요리재료_전처리         알레르기  \
# 1477          [콩나물, 양파, 쪽파, 멸치, 다시마, 청주, 다진마늘, 국간장, 천일염]            콩
# 2084                          [라면, 콩나물, 대파, 풋고추, 홍고추, 물]       밀가루, 콩
# 2193   [황태, 다시마육수, 무우, 계란, 다진마늘, 대파, 홍고추, 다시마, 물, 국간장...   콩, 난류, 견과류
# 2246   [국내산 냉장, 우거지, 대파, 양파, 된장, 청주, 후추, 고추가루, 된장, 청주...            콩
# 3163   [선지, 얼갈이, 양, 청양고추, 대파, 양파, 콩나물, 사골, 육수, 된장, 다진...            콩
# ...                                                  ...          ...
# 95185  [돼지등뼈, 무청, 월계수잎, 편생강, 사과 작은것, 대파, 청양고추, 건 새송이버...           돼지
# 95302  [배추잎, 부추, 파, 청양고추, 양파, 된장, 고추장, 간마늘, 올갱이, 육수티백...            콩
# 95327   [돼지등뼈, 설탕, 간마늘, 된장, 고춧가루, 설탕, 청양고추, 파, 배추김치, 된장]        돼지, 콩
# 96179  [소위, 한우양지, 통마늘, 대파, 콩나물, 무, 만능양념장, 고춧가루, 다진마늘,...  소, 연체동물류, 콩
# 97278  [돼지등뼈, 월계수잎, 건시래기, 양파, 대파, 된장, 청양고추, 다진 마늘, 다진...   콩, 돼지, 견과류
#
#        weighted_clipping
# 1477          220.142504
# 2084          303.953550
# 2193          311.161371
# 2246         1148.834385
# 3163          255.005659
# ...                  ...
# 95185         346.634614
# 95302         317.172405
# 95327         342.250719
# 96179         300.981517
# 97278         344.548770
#
# [177 rows x 15 columns]

# %% [markdown]
# # 사전 정의

# %% [markdown]
# # word2vec 기반
# - tfidf와 비교했을 때 w2v의 코사인이 카테고리 분류하지 않아도 유사한 레시피를 잘 찾아줌
# - w2v에서 CBOW와 Skip-Gram 사이의 정확도는 정확한 데이터가 있어야 비교 가능할 듯

# %% [markdown]
# 분리해야하는 세부카테고리 : 탕, 순대, 한식

# %%
#만개의 레시피 카테고리 사전
ckg_dict = {
    '요리방법별명' : ['끓이기', '굽기', '볶음', '튀김', '기타', '부침', '조림', '찜', '무침', '절임', '비빔', '데치기', '삶기', '회'],
    '요리상황별명' : ['일상', '술안주', '손님접대', '도시락', '야식', '간식', '영양식', '명절', '초스피드','다이어트', '해장', '이유식'],
    '요리재료별명' : ['쌀', '건어물류', '가공식품류', '버섯류', '닭고기', '해물류', '채소류', '육류', '밀가루','콩/견과류', '돼지고기', '달걀/유제품', '소고기', '곡류', '과일류'],
    '요리종류별명' : ['밥/죽/떡', '메인반찬', '면/만두', '양식', '밑반찬', '찌개', '국/탕', '김치/젓갈/장류', '퓨전']
}

# 만개의레시피의 카테고리를 기준으로 쿠팡의 세부 카테고리를 분류
coupang_dict = {
    '전골':'국/탕', 
    '생선탕':'해물류',
    '찌개/짜글이':'찌개', 
    '한식':'메인반찬,굽기', 
    '알탕':'해물류',
    '해물탕':'국/탕', 
    '기타':'null', 
    '국':'국/탕', 
    '씨푸드':'해물류', 
    '구이':'굽기',
    '찜':'찜', 
    '닭':'닭고기', 
    '면':'면/만두', 
    '국수':'면/만두', 
    '스테이크':'굽기,양식', 
    '파스타':'면/만두,양식', 
    '감바스':'양식', 
    '볶음':'볶음', 
    '떡볶이':'밥/죽/떡',
    '마파두부':'볶음', 
    '마라탕':'국/탕', 
    '쌈':'메인반찬', 
    '무침':'무침', 
    '샌드위치':'일상,기타', 
    '족발':'돼지고기', 
    '리조또':'밥/죽/떡', 
    '카레':'일상',
    '덮밥/비빔밥':'밥/죽/떡'
}

# 양념 재료 사전
sauce_dict = ['가루','설탕','간장','된장','식초','오일','액젓','소금','물','소주',
              '스프','고추장','고춧가루','사이다','소스','케첩','물엿','올리고당',
              '매실청','식용유','후추','젓갈','즙','정종','와인','맛술']

# %%
coupang_dict.keys()
# Out:
# dict_keys(['전골', '생선탕', '찌개/짜글이', '한식', '알탕', '해물탕', '기타', '국', '씨푸드', '구이', '찜', '닭', '면', '국수', '스테이크', '파스타', '감바스', '볶음', '떡볶이', '마파두부', '마라탕', '쌈', '무침', '샌드위치', '족발', '리조또', '카레', '덮밥/비빔밥'])

# %%
a = ['전골', '생선탕', '찌개/짜글이', '한식', '알탕', '해물탕', '기타', '국', '씨푸드', '구이', '찜', '닭', '면', '국수', '스테이크', '파스타', '감바스', '볶음', '떡볶이', '마파두부', '마라탕', '쌈', '무침', '샌드위치', '족발', '리조또', '카레', '덮밥/비빔밥']
a.sort()
print(a)
# Out:
# ['감바스', '구이', '국', '국수', '기타', '닭', '덮밥/비빔밥', '떡볶이', '리조또', '마라탕', '마파두부', '면', '무침', '볶음', '샌드위치', '생선탕', '스테이크', '쌈', '씨푸드', '알탕', '전골', '족발', '찌개/짜글이', '찜', '카레', '파스타', '한식', '해물탕']

# %%
len(a)
# Out:
# 28

# %%
##### 요리재료와 쿠팡 구성정보 일치 #####
def get_ingredients_pre(word):
    if ('소고기' in word)or('쇠고기' in word): word = '소고기'
    elif ('건면' in word)or('생면' in word)or('파스타 면' in word)or('파스타면' in word)or('라면 사리' in word)or('우동 사리' in word)or('라면사리' in word)or('우동사리' in word)or('칼국수 면' in word)or('칼국수면' in word)or('스파게티 면' in word)or('스파게티면' in word)or('페투치네' in word)or('우동면' in word)or('우동 면' in word)or('숙면' in word)or('소면' in word)or('쫄면' in word):word = '면'
    elif '고추장' in word: word = '고추장'
    elif ('고추' in word) and ('고추장' not in word): word = '고추'
    elif '새우젓' in word: word = '새우젓'
    elif ('새우' in word)and('새우젓' not in word): word = '새우'
    #elif '명태알 소스' in word: word = '명란'
    elif ('닭' in word)or('수비드 찜닭' in word): word = '닭'
    elif ('계란' in word)or('달걀' in word): word = '계란'
    elif ('소금' in word)or('천일염' in word): word = '소금'
    elif '다진' == word: word = '다진마늘'
    elif ('케첩' in word)or('케찹' in word): word = '케첩'
    elif ('식용유' in word)or('올리브유' in word)or('카놀라유' in word)or('기름' in word): word = '식용유'
    else:
        #단어 리스트에 있는 재료명 통일
        word_list = ['아귀','매생이','꼬막','가루','어묵','비엔나 소시지','대파','피망','파프리카','무우','양파','미역'
                     ,'오이','식초','간장','오일','스프','아보카도','물엿','올리고당','후추','젓갈','즙','와인','정종','액젓']
        for num in range(len(word_list)):
            if word_list[num] in word: 
                word = word_list[num]
    return word


##### input 값 전처리 후 list에 단어별 저장 #####
def get_product_list(num, product_df):
    # 상품명 전처리
    product = product_df.at[num, '상품_전처리'] #string으로 반환
    product_list = re.sub(r'[-=+,#/\?:^$.@*\"※~&%ㆍ!』\(\)]', '', product).split(' ') #특수문자제거(만개의레시피 데이터엔 특수문자가 없어서 인식 불가)
    product_list = list(filter(None, product_list)) #null 제거(안 할 경우 레시피 전체가 선택되어 작동 불가)
    
    #구성정보 전처리
    str_list = product_df.at[num, '구성정보_전처리']
    ingredients_list = str_list.split(',')
    
    #구성정보 요리재료명 통일
    for idx in range(len(ingredients_list)):
        ingredients_list[idx] = get_ingredients_pre(ingredients_list[idx])
    
    #구성정보 요리재료의 중복값 제거   
    result = []
    [result.append(x) for x in ingredients_list if x not in result]
    
    return product_list, result #쿠팡의 상품명, 구성정보_전처리의 요리재료명 반환


##### input 상품의 상세카테고리 추출 #####
def get_product_category(num, product_df):
    product_category = coupang_dict[coupang.at[num, '상세카테고리']].split(',') #리스트 반환
    ckg_key_value = {}
    if product_category == ['null']: #쿠팡의 상세카테고리==기타인 경우, null 반환
        ckg_key_value = {'null': 'null'}
    else:
        for category in product_category:
            for ckg_key in ckg_dict.keys(): #만개의레시피 해당 컬럼의 상세카테고리 리스트 저장
                ckg_value = ckg_dict.get(ckg_key) 
                if category in ckg_value: #만개의레시피 상세카테고리에 쿠팡 상세카테고리가 있으면
                    ckg_key_value[ckg_key] = category # { key=만개의레시피 해당컬럼 : value=해당컬럼의 상세 카테고리}로 저장
    return ckg_key_value


##### input 상품과 동일한 요리명 및 카테고리 의 레시피만 추출 #####
def get_recipe_df(product_list, ckg_key_value):
    #1차필터링
    recipe_df = pd.DataFrame() #추출한 만개의 레시피를 저장할 빈 df 생성
    for word in product_list:
        # 쿠팡상품명과 레시피요리명을 동일하게 변경
        if '보일링' in word: word = '해물찜'
        elif '씨 키트' in word: word = '해물'
        elif '냉동' in word: word = 'NaN' #쿠팡 상품명에 냉동이 있는 경우 제외하기 위한 값
        else: pass
        #해당 쿠팡 상품명 단어와 일치하는 요리명의 index만 저장
        recipe = ckg[ckg['요리명'].str.contains(word)] 
        recipe_df = pd.concat([recipe_df, recipe]) #위에서 생성한 df와 결합
    #2차 필터링
    recipe_df_filter = pd.DataFrame()
    for ckg_key in ckg_key_value.keys():
        if ckg_key == 'null': 
            #상세카테고리==기타 인 경우, 위의 df 그대로 사용 
            recipe_df_filter = recipe_df
        else:
            #해당하는 컬럼의 일치하는 상세카테고리만 저장
            recipe_df_key = recipe_df[recipe_df[f'{ckg_key}'] == ckg_key_value.get(ckg_key)]
            recipe_df_filter = pd.concat([recipe_df_filter, recipe_df_key])     
    #한번에 중복값 제거
    recipe_df_filter.drop_duplicates(subset=['레시피일련번호'], keep='first', inplace=True) 
    return recipe_df_filter


##### 추출한 만개의 레시피의 요리재료명 통일 및 word2vec을 위한 이중리스트 생성 #####
def get_recipe_pre(recipe_index, recipe_df):
    recipe_lists = []
    for index in recipe_index:
        man_ingredients = recipe_df.loc[index, '요리재료_전처리']
        # 요리재료가 word2vec을 위해 list형태로 저장
        # 반복문으로 재료명 통일
        recipe_list = []
        for man_ingredient in man_ingredients:
            man_ingredient = get_ingredients_pre(man_ingredient)
            # 추가할 필요가 없는 양념재료 제거
            # 양념 사전와 불일치하는 경우에만 recipe_list에 추가
            if man_ingredient in sauce_dict:
                pass
            else:
                recipe_list.append(man_ingredient)
        # 이중 리스트로 '요리재료_전처리' 전체 반환
        recipe_lists.append(recipe_list)
    return recipe_lists


###### 단어 벡터 평균구하기 ######
def vectors(embedding, embedding_model):
    word_embedding=[]
    dec2vec=None
    count=0
    for word in embedding:
        try : 
            # word에 해당하는 단어를 워드투백에서 찾아 리스트에 붙힘
            # 100차원으로 형성됨
            word_embedding.append(embedding_model.wv[word]) 
            count+=1
        except : continue

    word_embedding2=np.array(word_embedding)
    v=word_embedding2.sum(axis=0)  
    
    if type(v)!=np.ndarray:
        return np.zeros(100)
    
    return(v/count)


###### 최종 알고리즘 ######
def wv_mealkit(sim,mealkit_index,top_n,recipe_df):
    # 코사인유사도를 구한 행렬을 역순으로 정렬 -> 유사도가 높은 순의 인덱스로 정렬됨 
    sim_sorted_ind=sim.argsort()[:,::-1]
    
    # sim_indexes는 이중리스트 상태이므로 이중리스트를 해제한 후 인덱스를 이용해 해당 내용 추출
    similar_indexes=sim_sorted_ind[mealkit_index,1:(top_n+1)]
    recipe = recipe_df.iloc[similar_indexes]  #.sort_values(by='weighted_clipping',ascending=False) # 정렬은 우선 제외
    
    # 코사인 유사도 추출
    cos_num_all = []
    for s in similar_indexes:
        cos_num = [(i, k, s) for i in range(1141) for k in range(1141) if sim_sorted_ind[i][k]==s]
        cos_num_all.append(cos_num)
    test = []
    for sen in cos_num_all:
        cos_mean = [sim[i[0]][i[1]] for i in sen]
        test.append(np.mean(cos_mean))
    recipe['코사인 유사도'] = test
    return recipe


###### 레시피 only 재료 추출 ######
def get_recipe_only(ingredients_list, sim_mealkit_df):
    recipe_ingredient = []
    for idx in range(len(sim_mealkit_df)):
        value_list = sim_mealkit_df.요리재료_전처리.values[idx]
        
        value_set = [] #중복제거
        [value_set.append(x) for x in value_list if x not in value_set]
        
        for ingredient in ingredients_list:
            # input 구성정보와 요리재료가 일치하면 제외
            if ingredient in value_set:
                value_set.remove(ingredient)
        #레시피에만 있는 요리재료 추가
        recipe_ingredient.append(value_set)
    return recipe_ingredient

# %% [markdown]
# ## 실행코드
# - 알레르기: '갑각류, 견과류, 난류, 메밀, 밀가루, 우유, 연체동물류, 콩, 닭, 돼지, 복숭아, 소, 토마토, 생선류'

# %%
num = 60
allergy_num = ''

# %%
try:
    # coupang에서 input 값의 df 추출
    product_df = coupang.iloc[num:num+1, :]
    display(product_df[['상품명', '상세카테고리','구성정보_전처리','알레르기']])

    # input 상품명 및 구성정보 전처리 후 list로 추출
    product_list, ingredients_list = get_product_list(num, product_df)
except: 
    print("입력하신 번호의 쿠팡상품이 없습니다.")
    print('쿠팡 상품 개수 :', len(coupang))

try:
    ## 전처리
    ckg_key_value = get_product_category(num, product_df) # input 상품의 만개의 레시피와 일치하는 카테고리만 추출 {dict}
    recipe_df = get_recipe_df(product_list, ckg_key_value) # input 상품명과 일치하는 레시피만 추출
    #display(recipe_df[['요리명','요리방법별명','요리상황별명','요리재료별명','요리종류별명','요리재료_전처리','알레르기']])

    if len(recipe_df)==0: raise #일치하는 레시피가 아예 없는 경우 빈df 반환됨 == 에러발생

    if len(allergy_num) >= 1:
        recipe_df = recipe_df[~recipe_df['알레르기'].str.contains(allergy_num, na=False)] #알레르기 컬럼 추가

    recipe_index = recipe_df.index.tolist()
    word = get_recipe_pre(recipe_index, recipe_df)  # 일치하는 만개의 레시피 요리재료명 통일
    recipe_df['요리재료_전처리'] = word  # 통일한 요리재료명 업데이트

    ## word2vec 모델 적용
    word.append(ingredients_list) # word list의 가장 마지막에 input 구성정보 추가
    wv_model = Word2Vec(sentences=word, vector_size=100, window=20, min_count=1,  sg=1, batch_words=1000, alpha=0.03) # word2vec 모델 생성
    wordvec=[vectors(x, wv_model) for x in word] #레시피 별 벡터 평균 추출
    w2v_sim=cosine_similarity(wordvec,wordvec) # 코사인유사도 계산

    #레시피 추출
    mealkit_index = len(w2v_sim)-1 # 코사인유사도 행렬에서 input 상품의 인덱스 저장
    sim_mealkit_df = wv_mealkit(w2v_sim, mealkit_index, 5, recipe_df) #input 상품과 유사한 레시피 df 추출
    display(sim_mealkit_df[['레시피제목', '요리명','요리소개','요리재료_전처리','알레르기', '코사인 유사도']]) 
    
    #레시피에만 있는 재료 추출
    print('ingredients = ', ingredients_list)
    recipe_ingredients = get_recipe_only(ingredients_list, sim_mealkit_df)
    recipe_ingredients = list(filter(None, recipe_ingredients)) # input 구성정보와 요리재료가 모두 일치(빈리스트)하면 제외 
    pprint(recipe_ingredients)
    
except: 
    print("유사한 레시피가 없습니다.")
# Out:
#                                             상품명 상세카테고리      구성정보_전처리      알레르기
# 60  앙트레쿠킹박스 김치 꼬치어묵 우동전골 밀키트 2인분 (냉동), 870g, 1개     전골  어묵,우동면,소스,김치  생선류, 밀가루
# C:\Users\user\AppData\Local\Temp\ipykernel_9384\3237805010.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipe['코사인 유사도'] = test
#                      레시피제목    요리명  \
# 34854    백종원 어묵탕 국물의 계절 왔다    어묵탕
# 4406            매콤한 어묵꼬치탕   어묵꼬치탕
# 28366              어묵 꼬치탕   어묵꼬치탕
# 15235       얼큰하고 뜨끈한 매운어묵탕  매운어묵탕
# 72786  어묵 김치국 끓이기 해장국으로 딱!  어묵김치국
#
#                                                     요리소개  \
# 34854                                      겨울하면 생각나는 어묵탕
# 4406               쌀쌀한 날씨를 기분 좋게 즐길 수 있는 매콤한 어묵 꼬치탕입니다.
# 28366                  뭐 먹지 고민 될 땐~ 호불호가 없는 어묵탕이 최고~!!
# 15235  구하기 쉬운 재료의 대명사 어묵과 김치가 만나서 얼큰한 국물요리로 탄생하는 거죠. ...
# 72786  저희 신랑은 국을 엄청 좋아해요 없으면 안먹는건 아니지만 좋아하다보니 제가 매주 끓...
#
#                                                 요리재료_전처리              알레르기  \
# 34854                      [어묵, 면, 멸치, 양파, 대파, 간마늘, 다시마]       밀가루, 생선류, 콩
# 4406      [어묵, 대파, 무, 새우, 다시마, 김치, 면, 대파, 다진마늘, 청주, 혼다시]  갑각류, 생선류, 밀가루, 콩
# 28366  [어묵, 핫바, 어묵, 어묵, 멸치육수, 무, 쯔유, 대나무 꼬지   개, 와사비, 면]       밀가루, 생선류, 콩
# 15235                  [어묵, 양파, 김치, 파, 다진마늘, 무, 멸치, 다시마]            생선류, 콩
# 72786                                [어묵, 김치, 육수용멸치, 대파]            생선류, 콩
#
#         코사인 유사도
# 34854  0.999335
# 4406   0.999340
# 28366  0.999306
# 15235  0.999221
# 72786  0.999365
# ingredients =  ['어묵', '면', '소스', '김치']
# [['멸치', '양파', '대파', '간마늘', '다시마'],
#  ['대파', '무', '새우', '다시마', '다진마늘', '청주', '혼다시'],
#  ['핫바', '멸치육수', '무', '쯔유', '대나무 꼬지   개', '와사비'],
#  ['양파', '파', '다진마늘', '무', '멸치', '다시마'],
#  ['육수용멸치', '대파']]

# %% [markdown]
# - 84번 : 돔베고기....ㅠ
# - 95번 : 음.........
#
# > 세트구성인 경우 구성정보만 하나만 들어갔음. 추후 수정 필요..
